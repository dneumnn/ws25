# %% [markdown]
# # Exploring IBM Granite 4
#
# - <https://www.ibm.com/new/announcements/ibm-granite-4-0-hyper-efficient-high-performance-hybrid-models>
# - <https://huggingface.co/ibm-granite/granite-4.0-h-micro>

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
device = "mps"
model_path = "ibm-granite/granite-4.0-h-micro"
model = AutoModelForCausalLM.from_pretrained(model_path, device_map=device)
# Out:
# The fast path is not available because one of `(selective_state_update, causal_conv1d_fn, causal_conv1d_update)` is None. Falling back to the naive implementation. To install follow https://github.com/state-spaces/mamba/#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
model
# Out:
# GraniteMoeHybridForCausalLM(
#   (model): GraniteMoeHybridModel(
#     (embed_tokens): Embedding(100352, 2048, padding_idx=100256)
#     (layers): ModuleList(
#       (0-4): 5 x GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (mamba): GraniteMoeHybridMambaLayer(
#           (act): SiLUActivation()
#           (conv1d): Conv1d(4352, 4352, kernel_size=(4,), stride=(1,), padding=(3,), groups=4352)
#           (in_proj): Linear(in_features=2048, out_features=8512, bias=False)
#           (norm): GraniteMoeHybridRMSNormGated()
#           (out_proj): Linear(in_features=4096, out_features=2048, bias=False)
#         )
#       )
#       (5): GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (self_attn): GraniteMoeHybridAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#       )
#       (6-14): 9 x GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (mamba): GraniteMoeHybridMambaLayer(
#           (act): SiLUActivation()
#           (conv1d): Conv1d(4352, 4352, kernel_size=(4,), stride=(1,), padding=(3,), groups=4352)
#           (in_proj): Linear(in_features=2048, out_features=8512, bias=False)
#           (norm): GraniteMoeHybridRMSNormGated()
#           (out_proj): Linear(in_features=4096, out_features=2048, bias=False)
#         )
#       )
#       (15): GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (self_attn): GraniteMoeHybridAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#       )
#       (16-24): 9 x GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (mamba): GraniteMoeHybridMambaLayer(
#           (act): SiLUActivation()
#           (conv1d): Conv1d(4352, 4352, kernel_size=(4,), stride=(1,), padding=(3,), groups=4352)
#           (in_proj): Linear(in_features=2048, out_features=8512, bias=False)
#           (norm): GraniteMoeHybridRMSNormGated()
#           (out_proj): Linear(in_features=4096, out_features=2048, bias=False)
#         )
#       )
#       (25): GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (self_attn): GraniteMoeHybridAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#       )
#       (26-34): 9 x GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (mamba): GraniteMoeHybridMambaLayer(
#           (act): SiLUActivation()
#           (conv1d): Conv1d(4352, 4352, kernel_size=(4,), stride=(1,), padding=(3,), groups=4352)
#           (in_proj): Linear(in_features=2048, out_features=8512, bias=False)
#           (norm): GraniteMoeHybridRMSNormGated()
#           (out_proj): Linear(in_features=4096, out_features=2048, bias=False)
#         )
#       )
#       (35): GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (self_attn): GraniteMoeHybridAttention(
#           (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#           (k_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (v_proj): Linear(in_features=2048, out_features=512, bias=False)
#           (o_proj): Linear(in_features=2048, out_features=2048, bias=False)
#         )
#       )
#       (36-39): 4 x GraniteMoeHybridDecoderLayer(
#         (input_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (post_attention_layernorm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#         (shared_mlp): GraniteMoeHybridMLP(
#           (activation): SiLUActivation()
#           (input_linear): Linear(in_features=2048, out_features=16384, bias=False)
#           (output_linear): Linear(in_features=8192, out_features=2048, bias=False)
#         )
#         (mamba): GraniteMoeHybridMambaLayer(
#           (act): SiLUActivation()
#           (conv1d): Conv1d(4352, 4352, kernel_size=(4,), stride=(1,), padding=(3,), groups=4352)
#           (in_proj): Linear(in_features=2048, out_features=8512, bias=False)
#           (norm): GraniteMoeHybridRMSNormGated()
#           (out_proj): Linear(in_features=4096, out_features=2048, bias=False)
#         )
#       )
#     )
#     (norm): GraniteMoeHybridRMSNorm((2048,), eps=1e-05)
#   )
#   (lm_head): Linear(in_features=2048, out_features=100352, bias=False)
# )
